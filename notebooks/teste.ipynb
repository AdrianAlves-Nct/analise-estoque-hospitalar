# %%
import pandas as pd

# %%
df_estoque = pd.read_csv("../dados/estoque_atual.csv", sep=",")
df_consumo = pd.read_csv("../dados/consumo_mensal.csv", sep=",")

# %%
display(df_consumo)
# Out:
#             Data  Codigo             Produto                Grupo  \
# 0     2024-01-01      14     Furosemida 20mg          Medicamento
# 1     2024-01-01      20  Cateter Venoso 20G  Material Hospitalar
# 2     2024-01-01       4   Equipo Macrogotas  Material Hospitalar
# 3     2024-01-01      10      Ceftriaxona 1g          Antibiotico
# 4     2024-01-01      23      Compressa Gaze  Material Hospitalar
# ...          ...     ...                 ...                  ...
# 2268  2024-06-30       7         Agulha 25x7  Material Hospitalar
# 2269  2024-06-30      23      Compressa Gaze  Material Hospitalar
# 2270  2024-06-30      13    Ondansetrona 4mg          Medicamento
# 2271  2024-06-30      22   Mascara Cirurgica  Material Hospitalar
# 2272  2024-06-30       6        Seringa 20mL  Material Hospitalar
#
#                 Setor  Quantidade_Consumida
# 0            Urgencia                    14
# 1                 UTI                    18
# ...

# %%
display(df_estoque)
# Out:
#     Codigo                      Produto                Grupo  Estoque_Atual  \
# 0        1            Dipirona 500mg/mL          Medicamento            122
# 1        2  Soro Fisiologico 0,9% 500mL             Solucoes             91
# 2        3      Soro Glicosado 5% 500mL             Solucoes            478
# 3        4            Equipo Macrogotas  Material Hospitalar            891
# 4        5                 Seringa 10mL  Material Hospitalar            363
# 5        6                 Seringa 20mL  Material Hospitalar            479
# 6        7                  Agulha 25x7  Material Hospitalar            876
# 7        8          Luva Procedimento M  Material Hospitalar            495
# 8        9               Omeprazol 40mg          Medicamento            977
# 9       10               Ceftriaxona 1g          Antibiotico            504
# 10      11                Ampicilina 1g          Antibiotico            186
# ...
